# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

from E3Dpy import e3d_creator

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Define model parameters

# %%
mod_m1=e3d_creator.e3d_model('M1')
mod_m1.assign_model_parameters(10,1,0.05,10)
mod_m1.import_velocity('../Data/Antarctica_firn_vel_model.txt')
mod_m1.position_receivers(3,7,dx=0.5)
mod_m1.define_source(5,0.5)

# %% [markdown]
# ## Plot model

# %%
mod_m1.plot_model()
mod_m1.plot_velocity()

# %% [markdown]
# ## Export e3d parameter file

# %%
mod_m1.create_e3d_file(path='m1/')
# Out:
# File created: m1/M1_e3dmodel.txt
